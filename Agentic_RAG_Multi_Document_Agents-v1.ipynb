# %% [markdown]
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/examples/agent/multi_document_agents-v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multi-Document Agents (V1)
#
# In this guide, you learn towards setting up a multi-document agent over the LlamaIndex documentation.
#
# This is an extension of V0 multi-document agents with the additional features:
# - Reranking during document (tool) retrieval
# - Query planning tool that the agent can use to plan
#
#
# We do this with the following architecture:
#
# - setup a "document agent" over each Document: each doc agent can do QA/summarization within its doc
# - setup a top-level agent over this set of document agents. Do tool retrieval and then do CoT over the set of tools to answer a question.

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# !pip install llama_index llama-hub unstructured
# Out:
# Requirement already satisfied: llama_index in /usr/local/lib/python3.10/dist-packages (0.9.39)
# Requirement already satisfied: llama-hub in /usr/local/lib/python3.10/dist-packages (0.0.76)
# Requirement already satisfied: unstructured in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama_index) (2.0.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama_index) (3.9.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama_index) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama_index) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (2023.6.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama_index) (0.26.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama_index) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama_index) (1.23.5)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (1.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama_index) (1.5.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama_index) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama_index) (0.9.0)
# Requirement already satisfied: html2text in /usr/local/lib/python3.10/dist-packages (from llama-hub) (2020.1.16)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from llama-hub) (5.9.5)
# Requirement already satisfied: pyaml<24.0.0,>=23.9.7 in /usr/local/lib/python3.10/dist-packages (from llama-hub) (23.12.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from llama-hub) (1.3.4)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.11.2)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.10.0)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured) (2024.1.2)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.6.1)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.2.1)
# Requirement already satisfied: unstructured-client>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.16.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.14.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama_index) (4.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama_index) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama_index) (4.66.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama_index) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama_index) (1.7.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama_index) (1.10.14)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama_index) (1.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama_index) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama_index) (1.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama_index) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama_index) (0.14.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml<24.0.0,>=23.9.7->llama-hub) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama_index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama_index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama_index) (1.0.0)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (3.20.2)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (2.8.2)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama_index) (2023.3.post1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama_index) (1.2.0)

# %%
pip install cohere
# Out:
# Requirement already satisfied: cohere in /usr/local/lib/python3.10/dist-packages (4.45)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (3.9.1)
# Requirement already satisfied: backoff<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.2.1)
# Requirement already satisfied: fastavro<2.0,>=1.8 in /usr/local/lib/python3.10/dist-packages (from cohere) (1.9.3)
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (6.11.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.0.7)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (4.0.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata<7.0,>=6.0->cohere) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->cohere) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->cohere) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->cohere) (2023.11.17)

# %%
# !pip install llama_hub
# Out:
# Requirement already satisfied: llama_hub in /usr/local/lib/python3.10/dist-packages (0.0.76)
# Requirement already satisfied: html2text in /usr/local/lib/python3.10/dist-packages (from llama_hub) (2020.1.16)
# Requirement already satisfied: llama-index>=0.9.29 in /usr/local/lib/python3.10/dist-packages (from llama_hub) (0.9.39)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from llama_hub) (5.9.5)
# Requirement already satisfied: pyaml<24.0.0,>=23.9.7 in /usr/local/lib/python3.10/dist-packages (from llama_hub) (23.12.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from llama_hub) (1.3.4)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (2.0.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (3.9.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (0.6.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (2023.6.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (0.26.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (1.23.5)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (1.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (1.5.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (0.5.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index>=0.9.29->llama_hub) (0.9.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml<24.0.0,>=23.9.7->llama_hub) (6.0.1)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->llama_hub) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index>=0.9.29->llama_hub) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index>=0.9.29->llama_hub) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index>=0.9.29->llama_hub) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index>=0.9.29->llama_hub) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index>=0.9.29->llama_hub) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index>=0.9.29->llama_hub) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index>=0.9.29->llama_hub) (1.14.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index>=0.9.29->llama_hub) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index>=0.9.29->llama_hub) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index>=0.9.29->llama_hub) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index>=0.9.29->llama_hub) (4.66.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index>=0.9.29->llama_hub) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index>=0.9.29->llama_hub) (1.7.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index>=0.9.29->llama_hub) (1.10.14)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index>=0.9.29->llama_hub) (1.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index>=0.9.29->llama_hub) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index>=0.9.29->llama_hub) (1.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index>=0.9.29->llama_hub) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index>=0.9.29->llama_hub) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index>=0.9.29->llama_hub) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index>=0.9.29->llama_hub) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index>=0.9.29->llama_hub) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index>=0.9.29->llama_hub) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index>=0.9.29->llama_hub) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index>=0.9.29->llama_hub) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index>=0.9.29->llama_hub) (2023.3.post1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index>=0.9.29->llama_hub) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index>=0.9.29->llama_hub) (23.2)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Setup and Download Data
#
# In this section, we'll load in the LlamaIndex documentation.

# %%
domain = "docs.llamaindex.ai"
docs_url = "https://docs.llamaindex.ai/en/latest/"
# !wget -e robots=off --recursive --no-clobber --page-requisites --html-extension --convert-links --restrict-file-names=windows --domains {domain} --no-parent {docs_url}
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/supporting_modules/supporting_modules.html’
#
# docs.llamaindex.ai/     [ <=>                ] 216.28K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:50 (31.9 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/supporting_modules/supporting_modules.html’ saved [221467]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/module_guides/supporting_modules/service_context.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/module_guides/supporting_modules/service_context.html’
#
# docs.llamaindex.ai/     [ <=>                ] 226.15K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:50 (40.9 MB/s) - ‘docs.llamaindex.ai/en/latest/module_guides/supporting_modules/service_context.html’ saved [231577]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/index.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/index.html’
#
# docs.llamaindex.ai/     [ <=>                ] 215.78K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:50 (43.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/index.html’ saved [220954]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/agents.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/agents.html’
#
# docs.llamaindex.ai/     [ <=>                ] 768.91K  --.-KB/s    in 0.03s
#
# 2024-01-28 16:47:50 (24.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/agents.html’ saved [787362]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/callbacks.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/callbacks.html’
#
# docs.llamaindex.ai/     [ <=>                ] 450.69K  --.-KB/s    in 0.01s
#
# 2024-01-28 16:47:50 (37.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/callbacks.html’ saved [461502]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/composability.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/composability.html’
#
# docs.llamaindex.ai/     [ <=>                ] 227.29K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:50 (62.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/composability.html’ saved [232748]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/evaluation.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/evaluation.html’
#
# docs.llamaindex.ai/     [ <=>                ] 989.74K  --.-KB/s    in 0.04s
#
# 2024-01-28 16:47:50 (24.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/evaluation.html’ saved [1013489]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/example_notebooks.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/example_notebooks.html’
#
# docs.llamaindex.ai/     [ <=>                ] 212.80K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:50 (37.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/example_notebooks.html’ saved [217903]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/finetuning.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/finetuning.html’
#
# docs.llamaindex.ai/     [ <=>                ] 305.20K  --.-KB/s    in 0.009s
#
# 2024-01-28 16:47:50 (33.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/finetuning.html’ saved [312520]
#
# --2024-01-28 16:47:50--  https://docs.llamaindex.ai/en/latest/api_reference/indices.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices.html’
#
# docs.llamaindex.ai/     [ <=>                ] 245.80K  --.-KB/s    in 0.01s
#
# 2024-01-28 16:47:51 (21.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices.html’ saved [251695]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/list.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/list.html’
#
# docs.llamaindex.ai/     [ <=>                ] 284.98K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:51 (41.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/list.html’ saved [291815]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/table.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/table.html’
#
# docs.llamaindex.ai/     [ <=>                ] 355.38K  --.-KB/s    in 0.02s
#
# 2024-01-28 16:47:51 (19.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/table.html’ saved [363908]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/tree.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/tree.html’
#
# docs.llamaindex.ai/     [ <=>                ] 303.73K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:51 (49.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/tree.html’ saved [311022]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/vector_store.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/vector_store.html’
#
# docs.llamaindex.ai/     [ <=>                ] 247.43K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:51 (49.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/vector_store.html’ saved [253365]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/struct_store.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/struct_store.html’
#
# docs.llamaindex.ai/     [ <=>                ] 350.37K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:51 (43.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/struct_store.html’ saved [358779]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/kg.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/kg.html’
#
# docs.llamaindex.ai/     [ <=>                ] 293.73K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:51 (43.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/kg.html’ saved [300779]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/indices/empty.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/indices/empty.html’
#
# docs.llamaindex.ai/     [ <=>                ] 252.31K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:51 (42.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/indices/empty.html’ saved [258368]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llm_predictor.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llm_predictor.html’
#
# docs.llamaindex.ai/     [ <=>                ] 312.38K  --.-KB/s    in 0.01s
#
# 2024-01-28 16:47:51 (26.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llm_predictor.html’ saved [319882]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms.html’
#
# docs.llamaindex.ai/     [ <=>                ] 263.46K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:51 (42.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms.html’ saved [269786]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/anthropic.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/anthropic.html’
#
# docs.llamaindex.ai/     [ <=>                ] 253.63K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:51 (45.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/anthropic.html’ saved [259714]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/azure_openai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/azure_openai.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.46K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:51 (29.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/azure_openai.html’ saved [256474]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/huggingface.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/huggingface.html’
#
# docs.llamaindex.ai/     [ <=>                ] 261.71K  --.-KB/s    in 0.009s
#
# 2024-01-28 16:47:51 (30.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/huggingface.html’ saved [267996]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/langchain.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/langchain.html’
#
# docs.llamaindex.ai/     [ <=>                ] 238.67K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:51 (54.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/langchain.html’ saved [244397]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/gradient_base_model.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/gradient_base_model.html’
#
# docs.llamaindex.ai/     [ <=>                ] 246.56K  --.-KB/s    in 0.009s
#
# 2024-01-28 16:47:51 (27.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/gradient_base_model.html’ saved [252479]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/gradient_model_adapter.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/gradient_model_adapter.html’
#
# docs.llamaindex.ai/     [ <=>                ] 246.74K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:51 (33.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/gradient_model_adapter.html’ saved [252661]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/litellm.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/litellm.html’
#
# docs.llamaindex.ai/     [ <=>                ] 249.14K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:51 (32.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/litellm.html’ saved [255119]
#
# --2024-01-28 16:47:51--  https://docs.llamaindex.ai/en/latest/api_reference/llms/llama_cpp.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/llama_cpp.html’
#
# docs.llamaindex.ai/     [ <=>                ] 250.23K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:52 (41.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/llama_cpp.html’ saved [256232]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/openai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/openai.html’
#
# docs.llamaindex.ai/     [ <=>                ] 262.05K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:52 (30.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/openai.html’ saved [268339]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/openai_like.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/openai_like.html’
#
# docs.llamaindex.ai/     [ <=>                ] 263.00K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:52 (35.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/openai_like.html’ saved [269314]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/openllm.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/openllm.html’
#
# docs.llamaindex.ai/     [ <=>                ] 288.28K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:52 (35.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/openllm.html’ saved [295201]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/palm.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/palm.html’
#
# docs.llamaindex.ai/     [ <=>                ] 235.22K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:52 (55.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/palm.html’ saved [240865]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/predibase.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/predibase.html’
#
# docs.llamaindex.ai/     [ <=>                ] 215.60K  --.-KB/s    in 0.002s
#
# 2024-01-28 16:47:52 (93.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/predibase.html’ saved [220771]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/replicate.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/replicate.html’
#
# docs.llamaindex.ai/     [ <=>                ] 247.91K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:52 (51.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/replicate.html’ saved [253859]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/llms/xinference.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/llms/xinference.html’
#
# docs.llamaindex.ai/     [ <=>                ] 247.15K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:52 (50.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/llms/xinference.html’ saved [253086]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/memory.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/memory.html’
#
# docs.llamaindex.ai/     [ <=>                ] 301.88K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:52 (47.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/memory.html’ saved [309127]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/multi_modal.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/multi_modal.html’
#
# docs.llamaindex.ai/     [ <=>                ] 385.58K  --.-KB/s    in 0.01s
#
# 2024-01-28 16:47:52 (31.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/multi_modal.html’ saved [394829]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/multi_modal/openai.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/multi_modal/openai.html’
#
# docs.llamaindex.ai/     [ <=>                ] 264.39K  --.-KB/s    in 0.01s
#
# 2024-01-28 16:47:52 (26.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/multi_modal/openai.html’ saved [270734]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/multi_modal/replicate.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/multi_modal/replicate.html’
#
# docs.llamaindex.ai/     [ <=>                ] 260.02K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:52 (32.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/multi_modal/replicate.html’ saved [266259]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/node_postprocessor.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/node_postprocessor.html’
#
# docs.llamaindex.ai/     [ <=>                ] 929.31K  --.-KB/s    in 0.04s
#
# 2024-01-28 16:47:52 (25.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/node_postprocessor.html’ saved [951610]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api_reference/node.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/node.html’
#
# docs.llamaindex.ai/     [ <=>                ] 220.34K  --.-KB/s    in 0.003s
#
# 2024-01-28 16:47:52 (70.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/node.html’ saved [225626]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseComponent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseComponent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 224.94K  --.-KB/s    in 0.002s
#
# 2024-01-28 16:47:52 (140 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseComponent.html’ saved [230341]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseNode.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseNode.html’
#
# docs.llamaindex.ai/     [ <=>                ] 253.85K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:52 (40.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseNode.html’ saved [259941]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.Document.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.Document.html’
#
# docs.llamaindex.ai/     [ <=>                ] 249.78K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:52 (41.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.Document.html’ saved [255779]
#
# --2024-01-28 16:47:52--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageDocument.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageDocument.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.50K  --.-KB/s    in 0.002s
#
# 2024-01-28 16:47:53 (134 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageDocument.html’ saved [245244]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageNode.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageNode.html’
#
# docs.llamaindex.ai/     [ <=>                ] 247.72K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:53 (32.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageNode.html’ saved [253664]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.IndexNode.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.IndexNode.html’
#
# docs.llamaindex.ai/     [ <=>                ] 241.98K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:53 (46.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.IndexNode.html’ saved [247786]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.MetadataMode.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.MetadataMode.html’
#
# docs.llamaindex.ai/     [ <=>                ] 220.04K  --.-KB/s    in 0.003s
#
# 2024-01-28 16:47:53 (69.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.MetadataMode.html’ saved [225321]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.Node.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.Node.html’
#
# docs.llamaindex.ai/     [ <=>                ] 214.75K  --.-KB/s    in 0.003s
#
# 2024-01-28 16:47:53 (60.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.Node.html’ saved [219909]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeRelationship.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeRelationship.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.17K  --.-KB/s    in 0.003s
#
# 2024-01-28 16:47:53 (82.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeRelationship.html’ saved [228522]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeWithScore.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeWithScore.html’
#
# docs.llamaindex.ai/     [ <=>                ] 244.13K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:53 (43.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeWithScore.html’ saved [249993]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.ObjectType.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.ObjectType.html’
#
# docs.llamaindex.ai/     [ <=>                ] 220.06K  --.-KB/s    in 0.02s
#
# 2024-01-28 16:47:53 (13.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.ObjectType.html’ saved [225344]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.QueryBundle.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.QueryBundle.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.52K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:53 (37.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.QueryBundle.html’ saved [228884]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.RelatedNodeInfo.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.RelatedNodeInfo.html’
#
# docs.llamaindex.ai/     [ <=>                ] 226.57K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:53 (58.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.RelatedNodeInfo.html’ saved [232003]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.TextNode.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.TextNode.html’
#
# docs.llamaindex.ai/     [ <=>                ] 251.23K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:53 (36.7 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.TextNode.html’ saved [257255]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api/llama_index.schema.TransformComponent.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.TransformComponent.html’
#
# docs.llamaindex.ai/     [ <=>                ] 218.51K  --.-KB/s    in 0.01s
#
# 2024-01-28 16:47:53 (20.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.schema.TransformComponent.html’ saved [223750]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/playground.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/playground.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.94K  --.-KB/s    in 0.003s
#
# 2024-01-28 16:47:53 (66.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/playground.html’ saved [227270]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/prompts.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/prompts.html’
#
# docs.llamaindex.ai/     [ <=>                ] 304.07K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:53 (45.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/prompts.html’ saved [311370]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query.html’
#
# docs.llamaindex.ai/     [ <=>                ] 215.78K  --.-KB/s    in 0.002s
#
# 2024-01-28 16:47:53 (96.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query.html’ saved [220954]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers.html’
#
# docs.llamaindex.ai/     [ <=>                ] 229.05K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:53 (61.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers.html’ saved [234552]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/empty.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/empty.html’
#
# docs.llamaindex.ai/     [ <=>                ] 230.27K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:53 (52.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/empty.html’ saved [235801]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/kg.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/kg.html’
#
# docs.llamaindex.ai/     [ <=>                ] 311.22K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:53 (49.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/kg.html’ saved [318686]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/list.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/list.html’
#
# docs.llamaindex.ai/     [ <=>                ] 260.10K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:53 (47.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/list.html’ saved [266341]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/table.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/table.html’
#
# docs.llamaindex.ai/     [ <=>                ] 273.37K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:53 (44.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/table.html’ saved [279932]
#
# --2024-01-28 16:47:53--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/tree.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/tree.html’
#
# docs.llamaindex.ai/     [ <=>                ] 265.22K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:54 (49.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/tree.html’ saved [271590]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/vector_store.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/vector_store.html’
#
# docs.llamaindex.ai/     [ <=>                ] 625.23K  --.-KB/s    in 0.02s
#
# 2024-01-28 16:47:54 (39.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/vector_store.html’ saved [640240]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/retrievers/transform.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/transform.html’
#
# docs.llamaindex.ai/     [ <=>                ] 230.62K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:54 (49.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/retrievers/transform.html’ saved [236150]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/response_synthesizer.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/response_synthesizer.html’
#
# docs.llamaindex.ai/     [ <=>                ] 374.58K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:54 (43.3 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/response_synthesizer.html’ saved [383575]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines.html’
#
# docs.llamaindex.ai/     [ <=>                ] 218.19K  --.-KB/s    in 0.002s
#
# 2024-01-28 16:47:54 (94.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines.html’ saved [223423]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/graph_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/graph_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 227.35K  --.-KB/s    in 0.001s
#
# 2024-01-28 16:47:54 (236 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/graph_query_engine.html’ saved [232805]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/multistep_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/multistep_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 230.82K  --.-KB/s    in 0.009s
#
# 2024-01-28 16:47:54 (25.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/multistep_query_engine.html’ saved [236356]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.75K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:54 (43.4 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_query_engine.html’ saved [245501]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/transform_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/transform_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 227.17K  --.-KB/s    in 0.001s
#
# 2024-01-28 16:47:54 (248 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/transform_query_engine.html’ saved [232620]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/router_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/router_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 244.31K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:54 (38.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/router_query_engine.html’ saved [250175]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_router_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_router_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 239.73K  --.-KB/s    in 0.007s
#
# 2024-01-28 16:47:54 (32.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_router_query_engine.html’ saved [245488]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sub_question_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sub_question_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 287.70K  --.-KB/s    in 0.009s
#
# 2024-01-28 16:47:54 (30.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sub_question_query_engine.html’ saved [294609]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sql_join_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sql_join_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 243.77K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:54 (50.9 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sql_join_query_engine.html’ saved [249622]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/flare_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/flare_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 231.68K  --.-KB/s    in 0.001s
#
# 2024-01-28 16:47:54 (202 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/flare_query_engine.html’ saved [237237]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/citation_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/citation_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 246.44K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:54 (51.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/citation_query_engine.html’ saved [252355]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/knowledge_graph_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/knowledge_graph_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 233.00K  --.-KB/s    in 0.001s
#
# 2024-01-28 16:47:54 (241 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/knowledge_graph_query_engine.html’ saved [238590]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sql_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sql_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 288.52K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:54 (47.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/sql_query_engine.html’ saved [295447]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_engines/pandas_query_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/pandas_query_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 218.68K  --.-KB/s    in 0.009s
#
# 2024-01-28 16:47:54 (24.8 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_engines/pandas_query_engine.html’ saved [223929]
#
# --2024-01-28 16:47:54--  https://docs.llamaindex.ai/en/latest/api_reference/query/chat_engines.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines.html’
#
# docs.llamaindex.ai/     [ <=>                ] 339.30K  --.-KB/s    in 0.008s
#
# 2024-01-28 16:47:55 (40.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines.html’ saved [347440]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/simple_chat_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/simple_chat_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 235.81K  --.-KB/s    in 0.002s
#
# 2024-01-28 16:47:55 (100 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/simple_chat_engine.html’ saved [241470]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_question_chat_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_question_chat_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 238.19K  --.-KB/s    in 0.006s
#
# 2024-01-28 16:47:55 (39.2 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_question_chat_engine.html’ saved [243910]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_plus_context_chat_engine.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_plus_context_chat_engine.html’
#
# docs.llamaindex.ai/     [ <=>                ] 243.87K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:55 (60.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_plus_context_chat_engine.html’ saved [249718]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_bundle.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_bundle.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.64K  --.-KB/s    in 0.001s
#
# 2024-01-28 16:47:55 (182 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_bundle.html’ saved [226964]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api_reference/query/query_transform.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/query/query_transform.html’
#
# docs.llamaindex.ai/     [ <=>                ] 245.09K  --.-KB/s    in 0.005s
#
# 2024-01-28 16:47:55 (50.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/query/query_transform.html’ saved [250973]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api_reference/readers.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api_reference/readers.html’
#
# docs.llamaindex.ai/     [ <=>                ] 229.71K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:55 (50.1 MB/s) - ‘docs.llamaindex.ai/en/latest/api_reference/readers.html’ saved [235224]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api/llama_index.readers.download_loader.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.download_loader.html’
#
# docs.llamaindex.ai/     [ <=>                ] 217.73K  --.-KB/s    in 0.003s
#
# 2024-01-28 16:47:55 (62.0 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.download_loader.html’ saved [222954]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api/llama_index.readers.WikipediaReader.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.WikipediaReader.html’
#
# docs.llamaindex.ai/     [ <=>                ] 221.36K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:55 (58.6 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.WikipediaReader.html’ saved [226671]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api/llama_index.readers.YoutubeTranscriptReader.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.YoutubeTranscriptReader.html’
#
# docs.llamaindex.ai/     [ <=>                ] 223.60K  --.-KB/s    in 0.004s
#
# 2024-01-28 16:47:55 (60.5 MB/s) - ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.YoutubeTranscriptReader.html’ saved [228963]
#
# --2024-01-28 16:47:55--  https://docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleDirectoryReader.html
# Reusing existing connection to docs.llamaindex.ai:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleDirectoryReader.html’
#
# ...
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MetadataFilters.html... 1141.
# 1141-0
# Converting links in docs.llamaindex.ai/en/latest/examples/pipeline/query_pipeline_async.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/DeepLakeIndexDemo.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.TwitterTweetReader.html... 1134.
# 1134-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.TransformComponent.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/pdf_tables/recursive_retriever.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.TencentVectorDB.html... 1161.
# 1161-0
# Converting links in docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/q_and_a/unified_query.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/module_guides/indexing/index_guide.html... 1148.
# 1148-0
# Converting links in docs.llamaindex.ai/en/latest/module_guides/evaluating/contributing_llamadatasets.html... 1124.
# 1124-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/WebPageDemo.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/finetuning/gradient/gradient_fine_tuning.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/module_guides/models/prompts/usage_pattern.html... 1149.
# 1149-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.Node.html... 1124.
# 1124-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.GithubRepositoryReader.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/multi_modal/llava_multi_modal_tesla_10q.html... 1145.
# 1145-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/pgvector_sql_query_engine.html... 1145.
# 1145-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/knowledge_graph_query_engine.html... 1133.
# 1131-2
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.MarkdownNodeParser.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleMongoReader.html... 1128.
# 1128-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.WikipediaReader.html... 1130.
# 1130-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.RelatedNodeInfo.html... 1138.
# 1138-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/NotionDemo.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/examples/multi_modal/ChromaMultiModalDemo.html... 1134.
# 1134-0
# Converting links in docs.llamaindex.ai/en/latest/understanding/evaluating/cost_analysis/root.html... 1141.
# 1141-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/SupabaseVectorIndexDemo.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/examples/multi_modal/gpt4v_multi_modal_retrieval.html... 1142.
# 1142-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.TairVectorStore.html... 1153.
# 1153-0
# Converting links in docs.llamaindex.ai/en/latest/module_guides/querying/structured_outputs/output_parser.html... 1132.
# 1132-0
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/pydantic_tree_summarize.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/vector_stores.html... 1164.
# 1164-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_bundle.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/managed/zcpDemo.html... 1139.
# 1139-0
# Converting links in docs.llamaindex.ai/en/latest/examples/composable_indices/ComposableIndices-Prior.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_pydantic_program.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/RetrieverRouterQueryEngine.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/examples/evaluation/guideline_eval.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.SimpleVectorStore.html... 1165.
# 1165-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/vllm.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/anyscale.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/react_agent.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.HTMLNodeParser.html... 1135.
# 1135-0
# Converting links in docs.llamaindex.ai/en/latest/examples/chat_engine/chat_engine_context.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MyScaleVectorStore.html... 1159.
# 1159-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_engines/router_query_engine.html... 1162.
# 1162-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/openllm.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/retrievers/list.html... 1195.
# 1195-0
# Converting links in docs.llamaindex.ai/en/latest/examples/customization/llms/SimpleIndexDemo-Huggingface_camel.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/JSONalyze_query_engine.html... 1137.
# 1121-16
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/openai_agent_query_plan.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/GuardrailsDemo.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/gradient_base_model.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/chatbots/building_a_chatbot.html... 1140.
# 1140-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.CodeSplitter.html... 1139.
# 1139-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.PineconeVectorStore.html... 1161.
# 1161-0
# Converting links in docs.llamaindex.ai/en/latest/community/full_stack_projects.html... 1134.
# 1134-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/multi_doc_auto_retrieval/multi_doc_auto_retrieval.html... 1145.
# 1145-0
# Converting links in docs.llamaindex.ai/en/latest/optimizing/evaluation/e2e_evaluation.html... 1138.
# 1138-0
# Converting links in docs.llamaindex.ai/en/latest/examples/retrievers/composable_retrievers.html... 1135.
# 1135-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/ollama.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/litellm.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.PsychicReader.html... 1128.
# 1128-0
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/guidance_sub_question.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/graphsignal.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/deplot/DeplotReader.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/SQLRouterQueryEngine.html... 1135.
# 1135-0
# Converting links in docs.llamaindex.ai/en/latest/examples/metadata_extraction/MetadataExtractionSEC.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/docstore/MongoDocstoreDemo.html... 1122.
# 1122-0
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/refine.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/output_parsing/lmformatenforcer_pydantic_program.html... 1116.
# 1116-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/llms/palm.html... 1141.
# 1141-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/simple_directory_reader.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/examples/finetuning/embeddings/finetune_embedding.html... 1145.
# 1145-0
# Converting links in docs.llamaindex.ai/en/latest/community/integrations/trulens.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llama_dataset/labelled-rag-datasets.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseComponent.html... 1137.
# 1137-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/bedrock.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/gradient_model_adapter.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/module_guides/loading/ingestion_pipeline/transformations.html... 1132.
# 1132-0
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/structured_refine.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.MetadataMode.html... 1135.
# 1135-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llama_dataset/downloading_llama_datasets.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/ZepIndexDemo.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/docstore/DocstoreDemo.html... 1121.
# 1121-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.GoogleDocsReader.html... 1130.
# 1130-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.node_parser.get_root_nodes.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/openai_assistant_agent.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/module_guides/models/llms/local.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/examples/callbacks/OpenLLMetry.html... 1132.
# 1132-0
# Converting links in docs.llamaindex.ai/en/latest/use_cases/multimodal.html... 1150.
# 1150-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ChromaVectorStore.html... 1160.
# 1160-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/TwitterDemo.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/examples/retrievers/simple_fusion.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/node_postprocessor/MetadataReplacementDemo.html... 1143.
# 1143-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeWithScore.html... 1151.
# 1151-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_engines/retriever_router_query_engine.html... 1157.
# 1157-0
# Converting links in docs.llamaindex.ai/en/latest/understanding/putting_it_all_together/structured_data/Airbyte_demo.html... 1140.
# 1140-0
# Converting links in docs.llamaindex.ai/en/latest/getting_started/reading.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/use_cases/q_and_a/rag_cli.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/MilvusReaderDemo.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/FaissIndexDemo.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/embeddings/together.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/example_notebooks.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/examples/node_postprocessor/PrevNextPostprocessorDemo.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/examples/node_postprocessor/RecencyPostprocessorDemo.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/examples/query_engine/recursive_retriever_agents.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/JaguarIndexDemo.html... 1141.
# 1141-0
# Converting links in docs.llamaindex.ai/en/latest/examples/finetuning/llm_judge/pairwise/finetune_llm_judge.html... 1141.
# 1141-0
# Converting links in docs.llamaindex.ai/en/latest/examples/embeddings/llm_rails.html... 1120.
# 1120-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_transform.html... 1169.
# 1169-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MilvusVectorStore.html... 1145.
# 1145-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/simple_chat_engine.html... 1154.
# 1154-0
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/multi_document_agents.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/evaluation/answer_and_context_relevancy.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageDocument.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/examples/data_connectors/PineconeDemo.html... 1123.
# 1123-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/indices/tree.html... 1281.
# 1281-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/finetuning.html... 1215.
# 1215-0
# Converting links in docs.llamaindex.ai/en/latest/examples/low_level/evaluation.html... 1142.
# 1140-2
# Converting links in docs.llamaindex.ai/en/latest/examples/agent/react_agent_with_query_engine.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/evaluation/relevancy_eval.html... 1125.
# 1125-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.readers.JSONReader.html... 1127.
# 1127-0
# Converting links in docs.llamaindex.ai/en/latest/examples/llm/llama_2.html... 1133.
# 1133-0
# Converting links in docs.llamaindex.ai/en/latest/examples/index_structs/knowledge_graph/Neo4jKGIndexDemo.html... 1135.
# 1135-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/Timescalevector.html... 1155.
# 1155-0
# Converting links in docs.llamaindex.ai/en/latest/optimizing/fine-tuning/fine-tuning.html... 1164.
# 1164-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.AstraDBVectorStore.html... 1144.
# 1144-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.WeaviateVectorStore.html... 1151.
# 1151-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/query_engines.html... 1134.
# 1134-0
# Converting links in docs.llamaindex.ai/en/latest/examples/response_synthesizers/custom_prompt_synthesizer.html... 1129.
# 1129-0
# Converting links in docs.llamaindex.ai/en/latest/examples/vector_stores/WeaviateIndexDemo.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/community/faq/chat_engines.html... 1131.
# 1131-0
# Converting links in docs.llamaindex.ai/en/latest/examples/retrievers/you_retriever.html... 1123.
# 1123-0
# Converting links in docs.llamaindex.ai/en/latest/api_reference/query/chat_engines/condense_question_chat_engine.html... 1155.
# 1155-0
# Converting links in docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ZepVectorStore.html... 1162.
# 1162-0
# Converting links in docs.llamaindex.ai/en/latest/_static/mystnb.4510f1fc1dee50b3e5859aac5469c37c29e427902b24a333a5f9fcb2f0b3ac41.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/pygments.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/autodoc_pydantic.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/graphviz.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/styles/furo-extensions.css@digest=30d1aed668e5c3a91c3e3bf6a60b675221979f0e.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/css/algolia.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/css/custom.css... nothing to do.
# Converting links in docs.llamaindex.ai/en/latest/_static/styles/furo.css@digest=fad236701ea90a88636c2a8c73b44ae642ed2a53.css... nothing to do.
# Converted links in 711 files in 11 seconds.

# %%
from llama_hub.file.unstructured.base import UnstructuredReader
from pathlib import Path
from llama_index.llms import OpenAI
from llama_index import ServiceContext
from llama_index import download_loader, SimpleDirectoryReader

# %%
import os
import openai
import cohere

os.environ["OPENAI_API_KEY"] = "Your API Key goes here"
os.environ["COHERE_API_KEY"] = "Your API Key goes here"

# %%
reader = UnstructuredReader()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
all_files_gen = Path("./docs.llamaindex.ai/").rglob("*")
all_files = [f.resolve() for f in all_files_gen]

# %%
all_html_files = [f for f in all_files if f.suffix.lower() == ".html"]

# %%
len(all_html_files)
# Out:
# 703

# %%
from llama_index import Document

reader = UnstructuredReader()

# TODO: set to higher value if you want more docs
doc_limit = 100

docs = []
for idx, f in enumerate(all_html_files):
    if idx > doc_limit:
        break
    print(f"Idx {idx}/{len(all_html_files)}")
    loaded_docs = reader.load_data(file=f, split_documents=True)
    # Hardcoded Index. Everything before this is ToC for all pages
    start_idx = 72
    loaded_doc = Document(
        text="\n\n".join([d.get_content() for d in loaded_docs[72:]]),
        metadata={"path": str(f)},
    )
    print(loaded_doc.metadata["path"])
    docs.append(loaded_doc)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Idx 0/703
# /content/docs.llamaindex.ai/en/latest/search.html
# Idx 1/703
# /content/docs.llamaindex.ai/en/latest/genindex.html
# Idx 2/703
# /content/docs.llamaindex.ai/en/latest/index.html
# Idx 3/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.TairVectorStore.html
# Idx 4/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.SimpleVectorStore.html
# Idx 5/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MyScaleVectorStore.html
# Idx 6/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.MetalReader.html
# Idx 7/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.SingleStoreVectorStore.html
# Idx 8/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.PineconeReader.html
# Idx 9/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleMongoReader.html
# Idx 10/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.PathwayReader.html
# Idx 11/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.ChromaReader.html
# Idx 12/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.CassandraVectorStore.html
# Idx 13/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ExactMatchFilter.html
# Idx 14/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.TxtaiReader.html
# Idx 15/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ChromaVectorStore.html
# Idx 16/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.LangchainNodeParser.html
# Idx 17/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.SentenceSplitter.html
# Idx 18/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.QueryBundle.html
# Idx 19/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.PineconeVectorStore.html
# Idx 20/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.RedisVectorStore.html
# Idx 21/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.HierarchicalNodeParser.html
# Idx 22/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.RssReader.html
# Idx 23/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.TimescaleVectorStore.html
# Idx 24/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.RocksetVectorStore.html
# Idx 25/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ZepVectorStore.html
# Idx 26/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.get_root_nodes.html
# Idx 27/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.JSONReader.html
# Idx 28/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.IndexNode.html
# Idx 29/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.TextNode.html
# Idx 30/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeWithScore.html
# Idx 31/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.DocArrayInMemoryVectorStore.html
# Idx 32/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.ObsidianReader.html
# Idx 33/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.LanceDBVectorStore.html
# Idx 34/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.DashVectorStore.html
# Idx 35/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.MilvusReader.html
# Idx 36/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.DeepLakeReader.html
# Idx 37/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.Neo4jVectorStore.html
# Idx 38/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.StringIterableReader.html
# Idx 39/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.MyScaleReader.html
# Idx 40/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.MarkdownElementNodeParser.html
# Idx 41/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.WeaviateReader.html
# Idx 42/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.Document.html
# Idx 43/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.WeaviateVectorStore.html
# Idx 44/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.MarkdownNodeParser.html
# Idx 45/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.PGVectorStore.html
# Idx 46/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.DeepLakeVectorStore.html
# Idx 47/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.ElasticsearchReader.html
# Idx 48/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.DocArrayHnswVectorStore.html
# Idx 49/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.FilterCondition.html
# Idx 50/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.SlackReader.html
# Idx 51/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.VectorStoreQueryResult.html
# Idx 52/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.SimpleFileNodeParser.html
# Idx 53/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.ObjectType.html
# Idx 54/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.TwitterTweetReader.html
# Idx 55/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.BagelVectorStore.html
# Idx 56/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.DashVectorReader.html
# Idx 57/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.ReaderConfig.html
# Idx 58/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.get_leaf_nodes.html
# Idx 59/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.FilterOperator.html
# Idx 60/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.MetadataAwareTextSplitter.html
# Idx 61/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.SentenceWindowNodeParser.html
# Idx 62/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.AwaDBVectorStore.html
# Idx 63/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.BaseComponent.html
# Idx 64/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleDirectoryReader.html
# Idx 65/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.NodeRelationship.html
# Idx 66/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.SemanticSplitterNodeParser.html
# Idx 67/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.CognitiveSearchVectorStore.html
# Idx 68/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageNode.html
# Idx 69/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.QdrantVectorStore.html
# Idx 70/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.QdrantReader.html
# Idx 71/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.FaissVectorStore.html
# Idx 72/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.EpsillaVectorStore.html
# Idx 73/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.UnstructuredElementNodeParser.html
# Idx 74/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.OpensearchVectorStore.html
# Idx 75/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.SteamshipFileReader.html
# Idx 76/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.PGVectoRsStore.html
# Idx 77/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.OpensearchVectorClient.html
# Idx 78/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.TrafilaturaWebReader.html
# Idx 79/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.TokenTextSplitter.html
# Idx 80/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.NodeParser.html
# Idx 81/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.DiscordReader.html
# Idx 82/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.PDFReader.html
# Idx 83/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.TransformComponent.html
# Idx 84/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.ImageDocument.html
# Idx 85/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.Node.html
# Idx 86/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.BeautifulSoupWebReader.html
# Idx 87/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MongoDBAtlasVectorSearch.html
# Idx 88/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.MboxReader.html
# Idx 89/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.HTMLNodeParser.html
# Idx 90/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.HTMLTagReader.html
# Idx 91/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.NotionPageReader.html
# Idx 92/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.SimpleWebPageReader.html
# Idx 93/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MilvusVectorStore.html
# Idx 94/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.JSONNodeParser.html
# Idx 95/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.VectorStoreQuery.html
# Idx 96/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.MetalVectorStore.html
# Idx 97/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.schema.RelatedNodeInfo.html
# Idx 98/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.node_parser.CodeSplitter.html
# Idx 99/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.readers.MakeWrapper.html
# Idx 100/703
# /content/docs.llamaindex.ai/en/latest/api/llama_index.vector_stores.ElasticsearchStore.html

# %% [markdown]
# Define LLM + Service Context + Callback Manager

# %%
llm = OpenAI(temperature=0, model="gpt-3.5-turbo")
service_context = ServiceContext.from_defaults(llm=llm)

# %% [markdown]
# ## Building Multi-Document Agents
#
# In this section we show you how to construct the multi-document agent. We first build a document agent for each document, and then define the top-level parent agent with an object index.

# %%
from llama_index import VectorStoreIndex, SummaryIndex

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ### Build Document Agent for each Document
#
# In this section we define "document agents" for each document.
#
# We define both a vector index (for semantic search) and summary index (for summarization) for each document. The two query engines are then converted into tools that are passed to an OpenAI function calling agent.
#
# This document agent can dynamically choose to perform semantic search or summarization within a given document.
#
# We create a separate document agent for each city.

# %%
from llama_index.agent import OpenAIAgent
from llama_index import load_index_from_storage, StorageContext
from llama_index.tools import QueryEngineTool, ToolMetadata
from llama_index.node_parser import SentenceSplitter
import os
from tqdm.notebook import tqdm
import pickle


async def build_agent_per_doc(nodes, file_base):
    print(file_base)

    vi_out_path = f"./data/llamaindex_docs/{file_base}"
    summary_out_path = f"./data/llamaindex_docs/{file_base}_summary.pkl"
    if not os.path.exists(vi_out_path):
        Path("./data/llamaindex_docs/").mkdir(parents=True, exist_ok=True)
        # build vector index
        vector_index = VectorStoreIndex(nodes, service_context=service_context)
        vector_index.storage_context.persist(persist_dir=vi_out_path)
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=vi_out_path),
            service_context=service_context,
        )

    # build summary index
    summary_index = SummaryIndex(nodes, service_context=service_context)

    # define query engines
    vector_query_engine = vector_index.as_query_engine()
    summary_query_engine = summary_index.as_query_engine(
        response_mode="tree_summarize"
    )

    # extract a summary
    if not os.path.exists(summary_out_path):
        Path(summary_out_path).parent.mkdir(parents=True, exist_ok=True)
        summary = str(
            await summary_query_engine.aquery(
                "Extract a concise 1-2 line summary of this document"
            )
        )
        pickle.dump(summary, open(summary_out_path, "wb"))
    else:
        summary = pickle.load(open(summary_out_path, "rb"))

    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name=f"vector_tool_{file_base}",
                description=f"Useful for questions related to specific facts",
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name=f"summary_tool_{file_base}",
                description=f"Useful for summarization questions",
            ),
        ),
    ]

    # build agent
    function_llm = OpenAI(model="gpt-4")
    agent = OpenAIAgent.from_tools(
        query_engine_tools,
        llm=function_llm,
        verbose=True,
        system_prompt=f"""\
You are a specialized agent designed to answer queries about the `{file_base}.html` part of the LlamaIndex docs.
You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
""",
    )

    return agent, summary


async def build_agents(docs):
    node_parser = SentenceSplitter()

    # Build agents dictionary
    agents_dict = {}
    extra_info_dict = {}

    # # this is for the baseline
    # all_nodes = []

    for idx, doc in enumerate(tqdm(docs)):
        nodes = node_parser.get_nodes_from_documents([doc])
        # all_nodes.extend(nodes)

        # ID will be base + parent
        file_path = Path(doc.metadata["path"])
        file_base = str(file_path.parent.stem) + "_" + str(file_path.stem)
        agent, summary = await build_agent_per_doc(nodes, file_base)

        agents_dict[file_base] = agent
        extra_info_dict[file_base] = {"summary": summary, "nodes": nodes}

    return agents_dict, extra_info_dict

# %%
agents_dict, extra_info_dict = await build_agents(docs)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]
# latest_search
# latest_genindex
# latest_index
# api_llama_index.vector_stores.TairVectorStore
# api_llama_index.vector_stores.SimpleVectorStore
# api_llama_index.vector_stores.MyScaleVectorStore
# api_llama_index.readers.MetalReader
# api_llama_index.vector_stores.SingleStoreVectorStore
# api_llama_index.readers.PineconeReader
# api_llama_index.readers.SimpleMongoReader
# api_llama_index.readers.PathwayReader
# api_llama_index.readers.ChromaReader
# api_llama_index.vector_stores.CassandraVectorStore
# api_llama_index.vector_stores.ExactMatchFilter
# api_llama_index.readers.TxtaiReader
# api_llama_index.vector_stores.ChromaVectorStore
# api_llama_index.node_parser.LangchainNodeParser
# api_llama_index.node_parser.SentenceSplitter
# api_llama_index.schema.QueryBundle
# api_llama_index.vector_stores.PineconeVectorStore
# api_llama_index.vector_stores.RedisVectorStore
# api_llama_index.node_parser.HierarchicalNodeParser
# api_llama_index.readers.RssReader
# api_llama_index.vector_stores.TimescaleVectorStore
# api_llama_index.vector_stores.RocksetVectorStore
# api_llama_index.vector_stores.ZepVectorStore
# api_llama_index.node_parser.get_root_nodes
# api_llama_index.readers.JSONReader
# api_llama_index.schema.IndexNode
# api_llama_index.schema.TextNode
# api_llama_index.schema.NodeWithScore
# api_llama_index.vector_stores.DocArrayInMemoryVectorStore
# api_llama_index.readers.ObsidianReader
# api_llama_index.vector_stores.LanceDBVectorStore
# api_llama_index.vector_stores.DashVectorStore
# api_llama_index.readers.MilvusReader
# api_llama_index.readers.DeepLakeReader
# api_llama_index.vector_stores.Neo4jVectorStore
# api_llama_index.readers.StringIterableReader
# api_llama_index.readers.MyScaleReader
# api_llama_index.node_parser.MarkdownElementNodeParser
# api_llama_index.readers.WeaviateReader
# api_llama_index.schema.Document
# api_llama_index.vector_stores.WeaviateVectorStore
# api_llama_index.node_parser.MarkdownNodeParser
# api_llama_index.vector_stores.PGVectorStore
# api_llama_index.vector_stores.DeepLakeVectorStore
# api_llama_index.readers.ElasticsearchReader
# api_llama_index.vector_stores.DocArrayHnswVectorStore
# api_llama_index.vector_stores.FilterCondition
# api_llama_index.readers.SlackReader
# api_llama_index.vector_stores.VectorStoreQueryResult
# api_llama_index.node_parser.SimpleFileNodeParser
# api_llama_index.schema.ObjectType
# api_llama_index.readers.TwitterTweetReader
# api_llama_index.vector_stores.BagelVectorStore
# api_llama_index.readers.DashVectorReader
# api_llama_index.readers.ReaderConfig
# api_llama_index.node_parser.get_leaf_nodes
# api_llama_index.vector_stores.FilterOperator
# api_llama_index.node_parser.MetadataAwareTextSplitter
# api_llama_index.node_parser.SentenceWindowNodeParser
# api_llama_index.vector_stores.AwaDBVectorStore
# api_llama_index.schema.BaseComponent
# api_llama_index.readers.SimpleDirectoryReader
# api_llama_index.schema.NodeRelationship
# api_llama_index.node_parser.SemanticSplitterNodeParser
# api_llama_index.vector_stores.CognitiveSearchVectorStore
# api_llama_index.schema.ImageNode
# api_llama_index.vector_stores.QdrantVectorStore
# api_llama_index.readers.QdrantReader
# api_llama_index.vector_stores.FaissVectorStore
# api_llama_index.vector_stores.EpsillaVectorStore
# api_llama_index.node_parser.UnstructuredElementNodeParser
# api_llama_index.vector_stores.OpensearchVectorStore
# api_llama_index.readers.SteamshipFileReader
# api_llama_index.vector_stores.PGVectoRsStore
# api_llama_index.vector_stores.OpensearchVectorClient
# api_llama_index.readers.TrafilaturaWebReader
# api_llama_index.node_parser.TokenTextSplitter
# api_llama_index.node_parser.NodeParser
# api_llama_index.readers.DiscordReader
# api_llama_index.readers.PDFReader
# api_llama_index.schema.TransformComponent
# api_llama_index.schema.ImageDocument
# api_llama_index.schema.Node
# api_llama_index.readers.BeautifulSoupWebReader
# api_llama_index.vector_stores.MongoDBAtlasVectorSearch
# api_llama_index.readers.MboxReader
# api_llama_index.node_parser.HTMLNodeParser
# api_llama_index.readers.HTMLTagReader
# api_llama_index.readers.NotionPageReader
# api_llama_index.readers.SimpleWebPageReader
# api_llama_index.vector_stores.MilvusVectorStore
# api_llama_index.node_parser.JSONNodeParser
# api_llama_index.vector_stores.VectorStoreQuery
# api_llama_index.vector_stores.MetalVectorStore
# api_llama_index.schema.RelatedNodeInfo
# api_llama_index.node_parser.CodeSplitter
# api_llama_index.readers.MakeWrapper
# api_llama_index.vector_stores.ElasticsearchStore

# %% [markdown]
# ### Build Retriever-Enabled OpenAI Agent
#
# We build a top-level agent that can orchestrate across the different document agents to answer any user query.
#
# This `RetrieverOpenAIAgent` performs tool retrieval before tool use (unlike a default agent that tries to put all tools in the prompt).
#
# **Improvements from V0**: We make the following improvements compared to the "base" version in V0.
#
# - Adding in reranking: we use Cohere reranker to better filter the candidate set of documents.
# - Adding in a query planning tool: we add an explicit query planning tool that's dynamically created based on the set of retrieved tools.

# %%
# define tool for each document agent
all_tools = []
for file_base, agent in agents_dict.items():
    summary = extra_info_dict[file_base]["summary"]
    doc_tool = QueryEngineTool(
        query_engine=agent,
        metadata=ToolMetadata(
            name=f"tool_{file_base}",
            description=summary,
        ),
    )
    all_tools.append(doc_tool)

# %%
print(all_tools[0].metadata)
# Out:
# ToolMetadata(description='This document provides information on how to search for specific content within the Llama Index AI documentation.', name='tool_latest_search', fn_schema=<class 'llama_index.tools.types.DefaultToolFnSchema'>)

# %%
# define an "object" index and retriever over these tools
from llama_index import VectorStoreIndex
from llama_index.objects import (
    ObjectIndex,
    SimpleToolNodeMapping,
    ObjectRetriever,
)
from llama_index.retrievers import BaseRetriever
from llama_index.postprocessor import CohereRerank
from llama_index.tools import QueryPlanTool
from llama_index.query_engine import SubQuestionQueryEngine
from llama_index.llms import OpenAI

llm = OpenAI(model_name="gpt-4-0613")

tool_mapping = SimpleToolNodeMapping.from_objects(all_tools)
obj_index = ObjectIndex.from_objects(
    all_tools,
    tool_mapping,
    VectorStoreIndex,
)
vector_node_retriever = obj_index.as_node_retriever(similarity_top_k=10)


# define a custom retriever with reranking
class CustomRetriever(BaseRetriever):
    def __init__(self, vector_retriever, postprocessor=None):
        self._vector_retriever = vector_retriever
        self._postprocessor = postprocessor or CohereRerank(top_n=5)
        super().__init__()

    def _retrieve(self, query_bundle):
        retrieved_nodes = self._vector_retriever.retrieve(query_bundle)
        filtered_nodes = self._postprocessor.postprocess_nodes(
            retrieved_nodes, query_bundle=query_bundle
        )

        return filtered_nodes


# define a custom object retriever that adds in a query planning tool
class CustomObjectRetriever(ObjectRetriever):
    def __init__(self, retriever, object_node_mapping, all_tools, llm=None):
        self._retriever = retriever
        self._object_node_mapping = object_node_mapping
        self._llm = llm or OpenAI("gpt-4-0613")

    def retrieve(self, query_bundle):
        nodes = self._retriever.retrieve(query_bundle)
        tools = [self._object_node_mapping.from_node(n.node) for n in nodes]

        sub_question_sc = ServiceContext.from_defaults(llm=self._llm)
        sub_question_engine = SubQuestionQueryEngine.from_defaults(
            query_engine_tools=tools, service_context=sub_question_sc
        )
        sub_question_description = f"""\
Useful for any queries that involve comparing multiple documents. ALWAYS use this tool for comparison queries - make sure to call this \
tool with the original query. Do NOT use the other tools for any queries involving multiple documents.
"""
        sub_question_tool = QueryEngineTool(
            query_engine=sub_question_engine,
            metadata=ToolMetadata(
                name="compare_tool", description=sub_question_description
            ),
        )

        return tools + [sub_question_tool]

# %%
custom_node_retriever = CustomRetriever(vector_node_retriever)

# wrap it with ObjectRetriever to return objects
custom_obj_retriever = CustomObjectRetriever(
    custom_node_retriever, tool_mapping, all_tools, llm=llm
)

# %%
tmps = custom_obj_retriever.retrieve("hello")
print(len(tmps))
# Out:
# 6

# %%
 top_agent = ReActAgent.from_tools(
     tool_retriever=custom_obj_retriever,
     system_prompt=""" \
 You are an agent designed to answer queries about the documentation.
 Please always use the tools provided to answer a question. Do not rely on prior knowledge.\

 """,
     llm=llm,
     verbose=True,
 )

# %% [markdown]
# ### Define Baseline Vector Store Index
#
# As a point of comparison, we define a "naive" RAG pipeline which dumps all docs into a single vector index collection.
#
# We set the top_k = 4

# %%
all_nodes = [
    n for extra_info in extra_info_dict.values() for n in extra_info["nodes"]
]

# %%
base_index = VectorStoreIndex(all_nodes)
base_query_engine = base_index.as_query_engine(similarity_top_k=4)

# %% [markdown]
# ## Running Example Queries
#
# Let's run some example queries, ranging from QA / summaries over a single document to QA / summarization over multiple documents.

# %%
response = top_agent.query(
    "Tell me about LlamaIndex connectors"
)

#response = top_agent.as_query_component("Tell me about the different types of evaluation in LlamaIndex")
# Out:
# Thought: I need to use a tool to help me answer the question.
# Action: tool_latest_search
# Action Input: {'input': 'LlamaIndex connectors'}
# Added user message to memory: LlamaIndex connectors
# === Calling Function ===
# Calling function: vector_tool_latest_search with args: {
#   "input": "LlamaIndex connectors"
# }
# Got output: The LlamaIndex connectors can be found on the /content/docs.llamaindex.ai/en/latest/search.html page.
# ========================
#
# Observation: The LlamaIndex connectors are not specifically mentioned in the `latest_search.html` part of the LlamaIndex docs. You may need to check other sections of the documentation for detailed information about LlamaIndex connectors.
# Thought: I need to search for information about LlamaIndex connectors in a different tool.
# Action: tool_latest_index
# Action Input: {'input': 'LlamaIndex connectors'}
# Added user message to memory: LlamaIndex connectors
# === Calling Function ===
# Calling function: vector_tool_latest_index with args: {
#   "input": "LlamaIndex connectors"
# }
# Got output: LlamaIndex provides data connectors that allow you to ingest your existing data from various sources and formats. These connectors can work with APIs, PDFs, SQL, and more. By using LlamaIndex connectors, you can easily bring your data into the LlamaIndex ecosystem and make it accessible for natural language access and retrieval.
# ========================
#
# Observation: LlamaIndex offers data connectors that enable you to import your existing data from a variety of sources and formats. These connectors are compatible with APIs, PDFs, SQL, and more. Utilizing LlamaIndex connectors allows you to seamlessly integrate your data into the LlamaIndex ecosystem, making it readily available for natural language access and retrieval.
# Thought: I can answer without using any more tools.
# Answer: LlamaIndex connectors are used to import existing data from various sources and formats into the LlamaIndex ecosystem. These connectors are compatible with APIs, PDFs, SQL, and more, allowing seamless integration of data for natural language access and retrieval.

# %%
print(response)
# Out:
# LlamaIndex connectors are used to import existing data from various sources and formats into the LlamaIndex ecosystem. These connectors are compatible with APIs, PDFs, SQL, and more, allowing seamless integration of data for natural language access and retrieval.

# %%
# baseline
response = base_query_engine.query(
    "Tell me about LlamaIndex connectors"
)
print(str(response))
# Out:
# LlamaIndex provides data connectors that allow you to ingest your existing data from various sources such as APIs, PDFs, SQL, and more. These connectors retrieve data from their native sources and format it in intermediate representations that are easy for LlamaIndex's language models to consume. This enables natural language access to your data and allows you to perform powerful retrieval and query operations.

# %%
response = top_agent.query(
    "From the documentation what is the best way to get started with LlamaIndex?"
)
# Out:
# Thought: I can use the LlamaIndex documentation to find the best way to get started.
# Action: tool_latest_search
# Action Input: {'input': 'getting started with LlamaIndex'}
# Added user message to memory: getting started with LlamaIndex
# Observation: I'm sorry, but as an AI designed to answer queries about the `latest_search.html` part of the LlamaIndex docs, I don't have the ability to provide a guide on getting started with LlamaIndex. However, you can use the `vector_tool_latest_search` or `summary_tool_latest_search` to ask specific questions about the `latest_search.html` part of the LlamaIndex docs.
# Thought: It seems that the tool I used is specific to searching within the `latest_search.html` part of the LlamaIndex documentation. I should try a different tool to find information on getting started with LlamaIndex.
# Action: tool_latest_index
# Action Input: {'input': 'getting started with LlamaIndex'}
# Added user message to memory: getting started with LlamaIndex
# === Calling Function ===
# Calling function: vector_tool_latest_index with args: {
#   "input": "getting started with LlamaIndex"
# }
# Got output: To get started with LlamaIndex, you can install the library by running the following command:
#
# pip install llama-index
#
# After installing the library, you can refer to the documentation on how to use LlamaIndex based on your experience level. The documentation provides guidance for both beginner users and advanced users who want to customize and extend the different modules of LlamaIndex.
#
# Additionally, you can find LlamaIndex on GitHub and PyPi for downloading or contributing to the project. There is also a TypeScript/Javascript version available on NPM. If you need help or have any feature suggestions, you can join the LlamaIndex community on Twitter or Discord.
#
# LlamaIndex is designed to provide tools for beginners, advanced users, and everyone in between. It offers data connectors to ingest and query your existing data, data indexes to structure your data for LLMs, and engines for natural language access to your data. LlamaIndex can be used for various purposes such as knowledge-augmented output, conversational interfaces, and LLM-powered knowledge workers.
#
# Overall, LlamaIndex aims to make LLMs more relevant and useful to users by overcoming the weaknesses of the fine-tuning approach and providing a more trustworthy and up-to-date solution.
# ========================
#
# Observation: To get started with LlamaIndex, you first need to install the library by running the command `pip install llama-index`. Once installed, you can refer to the documentation which provides guidance for both beginner and advanced users.
#
# LlamaIndex is available on GitHub and PyPi for downloading or contributing to the project. There's also a TypeScript/Javascript version available on NPM. If you need help or have any feature suggestions, you can join the LlamaIndex community on Twitter or Discord.
#
# The library provides tools for beginners, advanced users, and everyone in between. It offers data connectors to ingest and query your existing data, data indexes to structure your data for LLMs, and engines for natural language access to your data. LlamaIndex can be used for various purposes such as knowledge-augmented output, conversational interfaces, and LLM-powered knowledge workers.
#
# LlamaIndex aims to make LLMs more relevant and useful to users by overcoming the weaknesses of the fine-tuning approach and providing a more trustworthy and up-to-date solution.
# Thought: I have found the information on getting started with LlamaIndex from the documentation.
# Answer: To get started with LlamaIndex, you need to install the library by running the command `pip install llama-index`. Once installed, you can refer to the documentation which provides guidance for both beginner and advanced users. LlamaIndex is available on GitHub and PyPi for downloading or contributing to the project. There's also a TypeScript/Javascript version available on NPM. If you need help or have any feature suggestions, you can join the LlamaIndex community on Twitter or Discord.
#
# The library provides tools for beginners, advanced users, and everyone in between. It offers data connectors to ingest and query your existing data, data indexes to structure your data for LLMs, and engines for natural language access to your data. LlamaIndex can be used for various purposes such as knowledge-augmented output, conversational interfaces, and LLM-powered knowledge workers.
#
# LlamaIndex aims to make LLMs more relevant and useful to users by overcoming the weaknesses of the fine-tuning approach and providing a more trustworthy and up-to-date solution.

# %%
print(response)
# Out:
# To get started with LlamaIndex, you need to install the library by running the command `pip install llama-index`. Once installed, you can refer to the documentation which provides guidance for both beginner and advanced users. LlamaIndex is available on GitHub and PyPi for downloading or contributing to the project. There's also a TypeScript/Javascript version available on NPM. If you need help or have any feature suggestions, you can join the LlamaIndex community on Twitter or Discord.
#
# The library provides tools for beginners, advanced users, and everyone in between. It offers data connectors to ingest and query your existing data, data indexes to structure your data for LLMs, and engines for natural language access to your data. LlamaIndex can be used for various purposes such as knowledge-augmented output, conversational interfaces, and LLM-powered knowledge workers.
#
# LlamaIndex aims to make LLMs more relevant and useful to users by overcoming the weaknesses of the fine-tuning approach and providing a more trustworthy and up-to-date solution.

# %%
response = top_agent.query(
    "What is pinecone"
)
# Out:
# Thought: (Implicit) I can answer without any more tools!
# Answer: Pinecone is a vector database that allows you to store, index, and search high-dimensional vectors. It provides a scalable and efficient solution for similarity search and nearest neighbor retrieval. With Pinecone, you can easily build applications that require fast and accurate similarity matching, such as recommendation systems, image search, and natural language processing.

# %%
print(str(response))
# Out:
# Pinecone is a vector database that allows you to store, index, and search high-dimensional vectors. It provides a scalable and efficient solution for similarity search and nearest neighbor retrieval. With Pinecone, you can easily build applications that require fast and accurate similarity matching, such as recommendation systems, image search, and natural language processing.
